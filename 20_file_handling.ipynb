# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 3EF7-F079
#
#  Directory of C:\Users\Admin\Advpython_Practice_Code
#
# 04-04-2026  22:41    <DIR>          .
# 03-04-2026  22:51    <DIR>          ..
# 04-04-2026  22:41    <DIR>          .ipynb_checkpoints
# 04-04-2026  11:11            12,936 18_oop_1.ipynb
# 04-04-2026  22:31            17,190 19_oop_2.ipynb
# 04-04-2026  22:34               617 20_file_handling.ipynb
#                3 File(s)         30,743 bytes
#                3 Dir(s)  108,709,224,448 bytes free

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 3EF7-F079
#
#  Directory of C:\Users\Admin\Advpython_Practice_Code
#
# 04-04-2026  22:41    <DIR>          .
# 03-04-2026  22:51    <DIR>          ..
# 04-04-2026  22:41    <DIR>          .ipynb_checkpoints
# 04-04-2026  11:11            12,936 18_oop_1.ipynb
# 04-04-2026  22:31            17,190 19_oop_2.ipynb
# 04-04-2026  22:34               617 20_file_handling.ipynb
#                3 File(s)         30,743 bytes
#                3 Dir(s)  108,709,466,112 bytes free

# %%
f = open('intro.txt','r')

# %%
f = open('intro.txt','w')

# %%
f.write("Hello my name is xyz. I have did my batchhelors in xyz field.")
# Out:
# 61

# %%
f.close()

# %%
f = open('intro.txt','r')

# %%
f.read()
# Out:
# 'Hello my name is xyz. I have did my batchhelors in xyz field.'

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Hello my name is xyz. I have did my batchhelors in xyz field.'

# %%
f.seek(4)
# Out:
# 4

# %%
f.read()
# Out:
# 'o my name is xyz. I have did my batchhelors in xyz field.'

# %%
f.seek(7)
# Out:
# 7

# %%
f.read()
# Out:
# 'y name is xyz. I have did my batchhelors in xyz field.'

# %%
f.write('hello')
# Out:
# 5

# %%
f.close()

# %%
f = open('intro.txt','r+') #both permisiion for read and write

# %%
f.read()
# Out:
# 'Hello my name is xyz. I have did my batchhelors in xyz field.This is my updated introhelloThis is my updated intro'

# %%
f.write('This is my updated intro')
# Out:
# 24

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Hello my name is xyz. I have did my batchhelors in xyz field.This is my updated introhelloThis is my updated introThis is my updated intro'

# %%
f = open('Agentic_ai.txt','w')

# %%
f.write(""" In a single word, deep learning is primarily used for prediction. 
Deep learning models excel at taking vast amounts of complex, unstructured data—such as images, text, and sound—and identifying subtle patterns to forecast outcomes or categorize information. While it performs many functions, almost all of them boil down to making a "prediction" about what the data represents or what will happen next. 
Amazon Web Services
Amazon Web Services
 +4
Why "Prediction" fits best:
Image Recognition: It predicts whether an image contains a specific object, such as a "cat" or a "stop sign".
Natural Language Processing: It predicts the most likely next word in a sentence or the correct translation of a phrase.
Generative AI: It predicts the sequence of pixels or characters needed to create entirely new content.
Finance & Healthcare: It predicts stock market trends, potential fraudulent transactions, or the likelihood of a disease based on medical scans.""")
# Out:
# 956

# %%
f.close()

# %%
f = open('Agentic_ai.txt', 'r+') # we have multiple lines

# %%
f.read()
# Out:
# ' In a single word, deep learning is primarily used for prediction. \nDeep learning models excel at taking vast amounts of complex, unstructured data—such as images, text, and sound—and identifying subtle patterns to forecast outcomes or categorize information. While it performs many functions, almost all of them boil down to making a "prediction" about what the data represents or what will happen next. \nAmazon Web Services\nAmazon Web Services\n +4\nWhy "Prediction" fits best:\nImage Recognition: It predicts whether an image contains a specific object, such as a "cat" or a "stop sign".\nNatural Language Processing: It predicts the most likely next word in a sentence or the correct translation of a phrase.\nGenerative AI: It predicts the sequence of pixels or characters needed to create entirely new content.\nFinance & Healthcare: It predicts stock market trends, potential fraudulent transactions, or the likelihood of a disease based on medical scans.'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# ' In a single word, deep learning is primarily used for prediction. \n'

# %%
f.readline()
# Out:
# 'Deep learning models excel at taking vast amounts of complex, unstructured data—such as images, text, and sound—and identifying subtle patterns to forecast outcomes or categorize information. While it performs many functions, almost all of them boil down to making a "prediction" about what the data represents or what will happen next. \n'

# %%
f.readline()
# Out:
# 'Amazon Web Services\n'

# %%
f.readline()
# Out:
# 'Amazon Web Services\n'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# ' In a single word, deep learning is primarily used for prediction. \n'

# %%
f.seek(0)
# Out:
# 0

# %%
for line in f.readlines():
    print(line)
# Out:
#  In a single word, deep learning is primarily used for prediction.
#
# Deep learning models excel at taking vast amounts of complex, unstructured data—such as images, text, and sound—and identifying subtle patterns to forecast outcomes or categorize information. While it performs many functions, almost all of them boil down to making a "prediction" about what the data represents or what will happen next.
#
# Amazon Web Services
#
# Amazon Web Services
#
#  +4
#
# Why "Prediction" fits best:
#
# Image Recognition: It predicts whether an image contains a specific object, such as a "cat" or a "stop sign".
#
# Natural Language Processing: It predicts the most likely next word in a sentence or the correct translation of a phrase.
#
# Generative AI: It predicts the sequence of pixels or characters needed to create entirely new content.
#
# Finance & Healthcare: It predicts stock market trends, potential fraudulent transactions, or the likelihood of a disease based on medical scans.

# %%
"Generative AI: It predicts the sequence of pixels or characters needed to create entirely new content.".split(' ')
# Out:
# ['Generative',
#  'AI:',
#  'It',
#  'predicts',
#  'the',
#  'sequence',
#  'of',
#  'pixels',
#  'or',
#  'characters',
#  'needed',
#  'to',
#  'create',
#  'entirely',
#  'new',
#  'content.']

# %%
f.seek(0)
# Out:
# 0

# %%
l = []
for line in f.readlines():
    l.append(line.split(' '))

# %%
l
# Out:
# [['',
#   'In',
#   'a',
#   'single',
#   'word,',
#   'deep',
#   'learning',
#   'is',
#   'primarily',
#   'used',
#   'for',
#   'prediction.',
#   '\n'],
#  ['Deep',
#   'learning',
#   'models',
#   'excel',
#   'at',
#   'taking',
#   'vast',
#   'amounts',
#   'of',
#   'complex,',
#   'unstructured',
#   'data—such',
#   'as',
#   'images,',
#   'text,',
#   'and',
#   'sound—and',
#   'identifying',
#   'subtle',
#   'patterns',
#   'to',
#   'forecast',
#   'outcomes',
#   'or',
#   'categorize',
#   'information.',
#   'While',
#   'it',
#   'performs',
#   'many',
#   'functions,',
#   'almost',
#   'all',
#   'of',
#   'them',
#   'boil',
#   'down',
#   'to',
#   'making',
#   'a',
#   '"prediction"',
#   'about',
#   'what',
#   'the',
#   'data',
#   'represents',
#   'or',
#   'what',
#   'will',
#   'happen',
#   'next.',
#   '\n'],
#  ['Amazon', 'Web', 'Services\n'],
#  ['Amazon', 'Web', 'Services\n'],
#  ['', '+4\n'],
# ...

# %%
f.seek(0)
# Out:
# 0

# %%
l2 = []

# %%
for char in f.readline():
    print(char)
# Out:
# D
# e
# e
# p
#
# l
# e
# a
# r
# n
# i
# n
# g
#
# m
# o
# d
# e
# l
# s
#
# e
# x
# c
# e
# l
#
# a
# t
#
# t
# a
# k
# i
# n
# g
#
# v
# a
# s
# t
#
# a
# m
# o
# u
# n
# t
# s
#
# o
# f
#
# c
# o
# m
# p
# l
# e
# x
# ,
#
# u
# n
# s
# t
# r
# u
# c
# t
# u
# r
# e
# d
#
# d
# a
# t
# a
# —
# s
# u
# c
# h
#
# a
# s
#
# i
# m
# a
# g
# e
# s
# ,
#
# t
# e
# x
# t
# ,
#
# a
# n
# d
#
# s
# o
# u
# n
# d
# —
# a
# n
# d
#
# i
# d
# e
# n
# t
# i
# f
# y
# i
# n
# g
#
# s
# u
# b
# t
# l
# e
#
# p
# a
# t
# t
# e
# r
# n
# s
#
# t
# o
#
# f
# o
# r
# e
# c
# a
# s
# t
#
# o
# u
# t
# c
# o
# m
# e
# s
#
# o
# r
#
# c
# a
# t
# e
# g
# o
# r
# i
# z
# e
#
# i
# n
# f
# o
# r
# m
# a
# t
# i
# o
# n
# .
#
# W
# h
# i
# l
# e
#
# i
# t
#
# p
# e
# r
# f
# o
# r
# m
# s
#
# m
# a
# n
# y
#
# f
# u
# n
# c
# t
# i
# o
# n
# s
# ,
#
# a
# l
# m
# o
# s
# t
#
# a
# l
# l
#
# o
# f
#
# t
# h
# e
# m
#
# b
# o
# i
# l
#
# d
# o
# w
# n
#
# t
# o
#
# m
# a
# k
# i
# n
# g
#
# a
#
# "
# p
# r
# ...

# %%
for char in f.readline():
    l2.append(char)

# %%
l2
# Out:
# ['A',
#  'm',
#  'a',
#  'z',
#  'o',
#  'n',
#  ' ',
#  'W',
#  'e',
#  'b',
#  ' ',
#  'S',
#  'e',
#  'r',
#  'v',
#  'i',
#  'c',
#  'e',
#  's',
#  '\n']

# %%
f.close()

# %%
# Overwrite

# %%
f = open('intro.txt', 'r+')

# %%
f.read()
# Out:
# 'Hello my name is xyz. I have did my batchhelors in xyz field.This is my updated introhelloThis is my updated introThis is my updated intro'

# %%
f.write('This is my new text')
# Out:
# 19

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 f.read()
#
# UnsupportedOperation: not readable

# %%
f.write('field')
# Out:
# 5

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 f.read()
#
# UnsupportedOperation: not readable
