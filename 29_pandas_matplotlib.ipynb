# %%
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Loc and iloc

# %%
data.loc[15:25,['Name','Age','Fare']]
# Out:
#                                                  Name   Age     Fare
# 15                   Hewlett, Mrs. (Mary D Kingcome)   55.0  16.0000
# 16                               Rice, Master. Eugene   2.0  29.1250
# 17                       Williams, Mr. Charles Eugene   NaN  13.0000
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  31.0  18.0000
# 19                            Masselmani, Mrs. Fatima   NaN   7.2250
# 20                               Fynney, Mr. Joseph J  35.0  26.0000
# 21                              Beesley, Mr. Lawrence  34.0  13.0000
# 22                        McGowan, Miss. Anna "Annie"  15.0   8.0292
# 23                       Sloper, Mr. William Thompson  28.0  35.5000
# 24                      Palsson, Miss. Torborg Danira   8.0  21.0750
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  38.0  31.3875

# %%
data.loc[15:25,['Age','Fare','Name',]]
# Out:
#      Age     Fare                                               Name
# 15  55.0  16.0000                   Hewlett, Mrs. (Mary D Kingcome)
# 16   2.0  29.1250                               Rice, Master. Eugene
# 17   NaN  13.0000                       Williams, Mr. Charles Eugene
# 18  31.0  18.0000  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19   NaN   7.2250                            Masselmani, Mrs. Fatima
# 20  35.0  26.0000                               Fynney, Mr. Joseph J
# 21  34.0  13.0000                              Beesley, Mr. Lawrence
# 22  15.0   8.0292                        McGowan, Miss. Anna "Annie"
# 23  28.0  35.5000                       Sloper, Mr. William Thompson
# 24   8.0  21.0750                      Palsson, Miss. Torborg Danira
# 25  38.0  31.3875  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...

# %%
# Split data

# %%
x = data.drop(columns= ['Fare'])

# %%
x
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
y = data['Fare']

# %%
y
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
x_columns = data.iloc[:, :-1]

# %%
x_columns
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
y_column = data['Embarked']

# %%
y_column
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: str

# %%
# missing / null values  --->  Fill --->
# id size is less ---> drop

# %%
data['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
data.dropna(inplace=True)

# %%
data['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Duplicates

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data.drop_duplicates(inplace= True)

# %% [markdown]
# # Groupby

# %%
data.groupby('Sex')['Fare'].mean()
# Out:
# Sex
# female    89.000900
# male      69.124343
# Name: Fare, dtype: float64

# %%
data.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    88.683228
# 2    18.444447
# 3    11.027500
# Name: Fare, dtype: float64

# %%
data.groupby('Pclass')['Fare'].sum()
# Out:
# Pclass
# 1    14011.9501
# 2      276.6667
# 3      110.2750
# Name: Fare, dtype: float64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.sort_values('Age')
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 305          306         1       1        Allison, Master. Hudson Trevor
# 183          184         1       2             Becker, Master. Richard F
# 205          206         0       3            Strom, Miss. Telma Matilda
# 297          298         0       1          Allison, Miss. Helen Loraine
# 340          341         1       2        Navratil, Master. Edmond Roger
# ..           ...       ...     ...                                   ...
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 456          457         0       1             Millet, Mr. Francis Davis
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 96            97         0       1             Goldschmidt, Mr. George B
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#         Sex    Age  SibSp  Parch     Ticket      Fare    Cabin Embarked
# ...

# %%
data.sort_values('Fare', ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 737          738         1       1                    Lesurer, Mr. Gustave J
# 679          680         1       1        Cardeza, Mr. Thomas Drake Martinez
# 27            28         0       1            Fortune, Mr. Charles Alexander
# 341          342         1       1            Fortune, Miss. Alice Elizabeth
# 438          439         0       1                         Fortune, Mr. Mark
# ..           ...       ...     ...                                       ...
# 75            76         0       3                   Moen, Mr. Sigurd Hansen
# 699          700         0       3  Humblen, Mr. Adolf Mathias Nicolai Olsen
# 872          873         0       1                  Carlsson, Mr. Frans Olof
# 263          264         0       1                     Harrison, Mr. William
# 806          807         0       1                    Andrews, Mr. Thomas Jr
#
# ...

# %%
data.sort_values('Fare')
# Out:
#      PassengerId  Survived  Pclass  \
# 263          264         0       1
# 806          807         0       1
# 872          873         0       1
# 75            76         0       3
# 715          716         0       3
# ..           ...       ...     ...
# 27            28         0       1
# 88            89         1       1
# 341          342         1       1
# 679          680         1       1
# 737          738         1       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 263                       Harrison, Mr. William    male  40.0      0      0
# 806                      Andrews, Mr. Thomas Jr    male  39.0      0      0
# 872                    Carlsson, Mr. Frans Olof    male  33.0      0      0
# 75                      Moen, Mr. Sigurd Hansen    male  25.0      0      0
# 715  Soholt, Mr. Peter Andreas Lauritz Andersen    male  19.0      0      0
# ..                                          ...     ...   ...    ...    ...
# ...

# %%
d1 = data.head(5)

# %%
d1
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
d2 = data.head(5)

# %%
d2
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
merge_data = pd.merge(d1,d2, on='PassengerId' )

# %%
merge_data
# Out:
#    PassengerId  Survived_x  Pclass_x  \
# 0            2           1         1
# 1            4           1         1
# 2            7           0         1
# 3           11           1         3
# 4           12           1         1
#
#                                               Name_x   Sex_x  Age_x  SibSp_x  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0        1
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0        1
# 2                            McCarthy, Mr. Timothy J    male   54.0        0
# 3                    Sandstrom, Miss. Marguerite Rut  female    4.0        1
# 4                           Bonnell, Miss. Elizabeth  female   58.0        0
#
#    Parch_x  Ticket_x   Fare_x  ... Pclass_y  \
# 0        0  PC 17599  71.2833  ...        1
# 1        0    113803  53.1000  ...        1
# 2        0     17463  51.8625  ...        1
# 3        1   PP 9549  16.7000  ...        3
# 4        0    113783  26.5500  ...        1
#
# ...

# %%
pd.concat([d1,d2])
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
# pivot table

# %%
pd.pivot_table(data, values = 'Fare',index='Pclass',aggfunc='mean')
# Out:
#              Fare
# Pclass
# 1       88.683228
# 2       18.444447
# 3       11.027500

# %%
pd.pivot_table(data, values = 'Fare',index='Sex',aggfunc='mean')
# Out:
#              Fare
# Sex
# female  89.000900
# male    69.124343

# %% [markdown]
# # Matplotlib

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.3 MB 349.3 kB/s eta 0:00:23
#    -- ------------------------------------- 0.5/8.3 MB 349.3 kB/s eta 0:00:23
#    -- ------------------------------------- 0.5/8.3 MB 349.3 kB/s eta 0:00:23
#    --- ------------------------------------ 0.8/8.3 MB 385.8 kB/s eta 0:00:20
#    --- ------------------------------------ 0.8/8.3 MB 385.8 kB/s eta 0:00:20
# ...

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [10,5,20,25]
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.title('sales data trend')
plt.xlabel('Days')
plt.ylabel('price')
plt.show()

# %%
names = ['A','B','C']
sales = [100,200,350]

# %%
plt.bar(names,sales, color= 'C1')
plt.title('Sales by names')
plt.show()

# %%
df = [10,20,20,30,30,30,20,40]

# %%
plt.hist(df)
plt.title('Data distribution')
plt.show()

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
y
# Out:
# [10, 5, 20, 25]

# %%
plt.scatter(x,y)
plt.title('Scatter Plot')
plt.show()

# %%
a = [1,2,3]
plt.plot(a,[10,20,30],label = 'Line 1')
plt.plot(a,[15,5,35],label = 'Line 2')

plt.legend()
plt.show()

# %%
plt.plot(x,y, color = 'red', linestyle='--',marker='o')
plt.show()
