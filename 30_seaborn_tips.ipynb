# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(data = df, x = 'Survived', y = 'Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='Sex'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df1 = sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data = df1, x ='tip', y='total_bill')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.relplot(data=df1, x='tip', y='total_bill', hue='smoker')

# %%
sns.relplot(data=df1, x='tip', y='total_bill', hue='time')

# %%
sns.relplot(data=df1, x='tip', y='total_bill', style='size')

# %%
sns.relplot(data=df1, x='tip', y='total_bill', style='sex')

# %%
sns.relplot(data=df1, x='tip', y='total_bill', style='day')

# %%
sns.relplot(data=df1, x='tip', y='total_bill', style='day', hue='size')

# %%
sns.relplot(data=df1, x='tip', y='total_bill', style='time', hue='smoker')

# %%
sns.relplot(data=df1, x='tip', y='total_bill', style='size', hue='sex')

# %%
sns.countplot(data=df1,  x='day')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(data=df,  x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.countplot(data=df, x='Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.barplot(data=df1, x='day', y='total_bill' )
plt.title('Number of customers per day')
plt.show()

# %%
sns.lineplot(data=df1, x='size', y='total_bill')
plt.title('Bill vs Tip')
plt.show()

# %%
sns.lineplot(data=df1, x='size', y='tip')
plt.title('Bill vs Tip')
plt.show()

# %%
sns.histplot(df1['total_bill'], bins=10)
plt.title = ('Bill distribution')
plt.show()

# %%
sns.histplot(df1['total_bill'], bins=5)
plt.title = ('Bill distribution')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.histplot(df1['total_bill'], bins=15)
plt.title = ('Bill distribution')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.boxplot(x='day',y='total_bill',data=df1)
plt.title('Bill Boxplot')
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 sns.boxplot(x='day',y='total_bill',data=df1)
# ----> 2 plt.title('Bill Boxplot')
#       3 plt.show
#
# TypeError: 'str' object is not callable

# %%
df1.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
df1[['total_bill','tip','size']].corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df1[['total_bill','tip','size']].corr(), annot = True)
# Out:
# <Axes: >
