# %%
for i in range(1,11):
print(i)
# Out:
#   Cell In[1], line 2
#     print(i)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
print(4+3
# Out:
#   Cell In[3], line 1
#     print(4+3
#              ^
# _IncompleteInputError: incomplete input

# %%
'hi' + 8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 'hi' + 8
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = int(input('Enter a int type pf data'))
print(a*a)
print(a/a)
print(a+a)
# Out:
# Enter a int type pf data 2
# 4
# 1.0
# 4

# %%
a = int(input('Enter a int type pf data'))
print(a*a)
print(a/a)
print(a+a)
# Out:
# Enter a int type pf data 1.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a = int(input('Enter a int type pf data'))
#       2 print(a*a)
#       3 print(a/a)
#
# ValueError: invalid literal for int() with base 10: '1.5'

# %%
try:
    'hi' + 8
except:
    print('Error happenend in try block')
# Out:
# Error happenend in try block

# %%
try: 
    a = int(input('Write int num'))
    b = int(input('Write int num'))
except:
    print('written wrong type on input')

try:
    result = a/b
    print(result)
except:
    print('not possible to device')
try:
    result = a * b
    print(result)
except:
    print('can multiply a with b')
# Out:
# Write int num 5
# Write int num 0
# not possible to device
# 0

# %%
try:
    print(5/0)
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try:
    print(5/0)
except Exception as e:
    print('error in the try block, as below')
    print(e)
# Out:
# error in the try block, as below
# division by zero

# %%
def division(a,b):
    try:
        result = a/b
        print(result)
    except Exception as e:
        print(e)

# %%
division(10,3)
# Out:
# 3.3333333333333335

# %%
division(5,0)
# Out:
# division by zero

# %%
try:
    f = 10+ i
except Exception as e:
    print(e)
finally:
    print('Project completed')
# Out:
# name 'i' is not defined
# Project completed

# %%
try:
    f = open('google.py', 'r')
    f.read()
except Exception as e:
    print(e)
finally:
    print('Project completed')
# Out:
# [Errno 2] No such file or directory: 'google.py'
# Project completed
