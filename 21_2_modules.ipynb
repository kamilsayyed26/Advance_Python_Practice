# %%
summation(3,22,2)
# Out:
# 27

# %%
from imp_funtions import summation

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import imp_funtions as imp

# %%
imp.summation(12,4,69,65)
# Out:
# 150

# %%
imp.multiply(55,66)
# Out:
# 3630
